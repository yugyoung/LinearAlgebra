# %%
import gensim 

korea_docu = []
with open("korea.txt", encoding='utf-8') as file:
    for j, line in enumerate(file):
        korea_docu.append(gensim.utils.simple_preprocess(line))

korea_model = gensim.models.Word2Vec (korea_docu, size=5, window=5, min_count=1, workers=4)
korea_model.train(korea_docu, total_examples=len(korea_docu), epochs=1000)
# Out:
# (5314423, 8553000)

# %%
wordlist = []
count = []
for word, obj in korea_model.wv.vocab.items():
    wordlist.append(word)
    count.append(obj.count)
for _ in range(100):
    idx = count.index(max(count))
    print(wordlist[idx], max(count))
    del count[idx]
    del wordlist[idx]
# Out:
# the 944
# of 555
# shall 332
# and 326
# to 226
# be 226
# by 180
# or 135
# national 133
# in 121
# act 115
# assembly 98
# state 91
# president 83
# as 67
# for 66
# may 66
# under 62
# members 59
# constitution 49
# prescribed 47
# not 47
# court 45
# citizens 42
# public 41
# have 41
# all 40
# is 38
# on 37
# other 37
# with 36
# council 35
# conditions 34
# office 33
# determined 32
# executive 31
# matters 30
# from 29
# it 29
# case 29
# an 27
# this 27
# no 25
# their 23
# necessary 23
# right 23
# that 23
# political 22
# when 21
# prime 21
# minister 21
# supreme 21
# any 20
# such 20
# military 19
# within 19
# law 18
# provided 18
# at 18
# appointed 18
# time 17
# person 17
# are 17
# more 17
# pertaining 17
# rights 16
# its 16
# organization 16
# constitutional 16
# except 16
# who 16
# justices 16
# election 16
# than 15
# term 15
# total 15
# economic 14
# basic 14
# duty 14
# officials 14
# without 14
# he 14
# martial 14
# important 14
# they 14
# member 14
# affairs 14
# republic 13
# korea 13
# security 13
# request 13
# his 13
# judges 13
# days 13
# justice 12
# order 12
# freedom 12
# treaties 12
# laws 12
# nor 12

# %%
import numpy as np

v1 = korea_model.wv['citizens']
dotlist = []
wordlist = []
for word, obj in korea_model.wv.vocab.items():
    wordlist.append(word)
    w = korea_model.wv[word]
    dotlist.append(abs(np.dot(v1, w) / np.linalg.norm(v1) / np.linalg.norm(w)))

for _ in range(100):
    idx = dotlist.index(min(dotlist))
    print(wordlist[idx], min(dotlist))
    del dotlist[idx]
    del wordlist[idx]
# Out:
# judiciary 0.0017672761
# accredit 0.0020427613
# otherwise 0.002403285
# distribution 0.0024991482
# disqualified 0.0032715548
# treason 0.0038602531
# five 0.0053571514
# food 0.005790749
# audit 0.0072713937
# there 0.007428199
# envoys 0.008054554
# run 0.009743824
# written 0.010048455
# held 0.010415805
# investigation 0.01140741
# commutation 0.012313361
# further 0.013109832
# responsible 0.013132484
# insurrection 0.014112067
# growth 0.015217415
# executed 0.015666865
# matter 0.015698366
# views 0.015884113
# unification 0.016118554
# apprehended 0.01662551
# march 0.016943045
# defending 0.019107528
# less 0.019280657
# incumbent 0.019574208
# foreign 0.020242644
# performance 0.020393444
# stationing 0.02183948
# controlled 0.022375287
# event 0.022896968
# rules 0.023170486
# servicemen 0.024241816
# proper 0.024436994
# land 0.024573429
# himself 0.024617542
# observing 0.024718013
# charged 0.02535497
# adjudicated 0.02670472
# states 0.02694929
# improving 0.027373027
# autonomy 0.027571753
# become 0.027792761
# educational 0.02830546
# successors 0.028590461
# sexes 0.02890181
# agricultural 0.029582772
# lower 0.029653275
# also 0.030582909
# governed 0.03120102
# natural 0.031302776
# final 0.031373397
# until 0.031613745
# equilibrium 0.031679526
# he 0.03288951
# martial 0.033048246
# torture 0.03376435
# drill 0.03388518
# has 0.035323437
# fisheries 0.03568755
# analysis 0.03583183
# receives 0.03630436
# documents 0.036341295
# enumerated 0.037470058
# forty 0.0376352
# types 0.03891613
# strengthening 0.03900043
# obligatory 0.039399203
# generally 0.04234315
# sum 0.042798027
# alien 0.043709554
# establishment 0.044261236
# funds 0.044548728
# motion 0.044690926
# issued 0.045371994
# stability 0.04566561
# imposed 0.04587881
# ii 0.046062835
# competence 0.046892665
# like 0.048127223
# implement 0.048965327
# jurisdiction 0.048992433
# countersigned 0.050546724
# expropriation 0.05058173
# dispatch 0.051155727
# termination 0.05219257
# into 0.05253121
# composed 0.05253191
# danger 0.053810973
# organization 0.05552117
# exist 0.055893913
# sub 0.057330787
# cause 0.058009677
# basic 0.05816183
# extraordinary 0.058241345
# territory 0.05850234
# mutual 0.05865932

# %%
v = ['citizens', 'distribution']

A = np.array([korea_model.wv[v[i]] for i in range(len(v))])
A = A.T
P = np.dot(A,np.dot(np.linalg.inv(np.dot(A.T, A)), A.T))

dotlist = []
wordlist = []
for word, obj in korea_model.wv.vocab.items():
    wordlist.append(word)
    w = korea_model.wv[word] / np.linalg.norm(w)
    
    dotlist.append(abs(np.linalg.norm(np.dot(P, w))))

for _ in range(100):
    idx = dotlist.index(min(dotlist))
    print(wordlist[idx], min(dotlist))
    del dotlist[idx]
    del wordlist[idx]
# Out:
# [[ 0.02025628  0.01357092 -0.00869751 -0.13637389 -0.03143732]
#  [ 0.01357092  0.07866107  0.24746932 -0.10509966 -0.00152817]
#  [-0.00869751  0.24746932  0.9259693   0.00854927  0.08461897]
#  [-0.13637389 -0.10509965  0.00854927  0.92083865  0.20779312]
#  [-0.03143732 -0.00152817  0.08461897  0.20779313  0.05427474]]
# this 1.0289926e-07
# death 1.4024388e-07
# statement 1.4168043e-07
# claim 1.6122404e-07
# proceedings 1.7194056e-07
# military 1.7354071e-07
# pronounced 1.7967717e-07
# qualified 1.8576938e-07
# indicted 1.901833e-07
# bodily 1.9231224e-07
# entitled 1.9736197e-07
# ground 1.9819164e-07
# crimes 2.102653e-07
# official 2.1441232e-07
# innocent 2.3575804e-07
# corresponding 2.4041358e-07
# martial 2.458759e-07
# reasons 2.548482e-07
# compensations 2.7831254e-07
# absence 2.8281355e-07
# sentry 3.2313892e-07
# damages 3.3518631e-07
# proclamation 3.6160142e-07
# conformity 3.7191333e-07
# immune 3.737739e-07
# aid 4.339253e-07
# speedy 4.5010557e-07
# combat 4.5169963e-07
# officially 4.5998556e-07
# judgment 4.6294466e-07
# food 4.7175098e-07
# votes 5.4837585e-07
# employee 6.1087485e-07
# so 6.656505e-07
# important 6.876675e-07
# give 6.9381093e-07
# connection 7.4979465e-07
# member 7.5521785e-07
# others 8.1366323e-07
# prisoners 8.428811e-07
# acquire 8.798708e-07
# supply 9.211894e-07
# outside 9.64308e-07
# information 1.0067286e-06
# governmental 1.011563e-06
# petitions 1.0193236e-06
# high 1.029854e-06
# obligated 1.0684776e-06
# term 1.2286389e-06
# contracts 1.2302949e-06
# hold 1.2500237e-06
# paid 1.2986978e-06
# interests 1.4603219e-06
# constituencies 1.4782763e-06
# petition 1.4820113e-06
# representation 1.553245e-06
# released 1.8000203e-06
# disease 1.8544298e-06
# positions 1.946009e-06
# elected 1.9801776e-06
# direct 2.3493633e-06
# concurrently 2.4591145e-06
# apprehension 2.9378996e-06
# iii 3.0062545e-06
# opening 3.1045877e-06
# enumerated 3.1110847e-06
# organizations 3.1239072e-06
# convened 3.2300118e-06
# year 3.5734981e-06
# less 4.169119e-06
# vested 4.2825995e-06
# physical 4.520994e-06
# ballot 5.3766967e-06
# least 5.4151865e-06
# vice 5.9990602e-06
# expropriation 6.6721173e-06
# at 9.509367e-06
# governed 9.7952e-06
# continue 9.8111e-06
# institutions 1.0218393e-05
# school 1.0962311e-05
# move 1.0970382e-05
# committed 1.1000043e-05
# unfavorable 1.1810833e-05
# doing 1.2038067e-05
# convening 1.2474124e-05
# age 1.3129695e-05
# closed 1.3468495e-05
# otherwise 1.3605841e-05
# earning 1.3638265e-05
# fulfillment 1.4400774e-05
# children 1.4509855e-05
# specified 1.4969108e-05
# one 1.5244496e-05
# disasters 1.5359625e-05
# news 1.55217e-05
# newspapers 1.5824557e-05
# means 1.5928077e-05
# relative 1.5985826e-05
# compulsory 1.6006376e-05
