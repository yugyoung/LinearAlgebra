# %% [markdown]
# # Week 04
#
# ## Lecture 07 (19/3/18)
#
# ### To Do
#
# * Review previous lecture
# * Re-announce how to upload homework on LMS
# * Check roster
#
# ### Contents (3.1-3.2)
#
# * Inner product
#   * Definition: $a\circ b = a^Tb$
#   * **Q** Show that for any two vectors $v,w$ with internal angle $\theta$, the following holds.
#     $$v\cdot w = \Vert v\Vert\Vert w\Vert\cos\theta$$
#
# * Orthogonality
#   * Definition: $v\perp w$ if $v^Tw = 0$.
#   * (Fundamental Theorem of Linear Algebra I) $R(A)\perp N(A)$, $C(A)\perp N(A^T)$
#   * Example: $A = \begin{bmatrix}1 & 2 & 1\\ 2 & 4 & 3\\ 3 & 6 & 4\end{bmatrix}$.
#
# * Orthogonal complement
#   * (Fundamental Theorem of Linear Algebra II) $C(A)^\perp = N(A^T)$, $R(A)^\perp = N(A)$
#   * (Solvability) $Ax=b$ is solvable if and only if $y^Tb = 0$ for all $y$ satisfying $y^TA=0$ (That is, $y\in N^(A^T)$).
#
# * Schwartz inequality
#   * $|a^Tb| \le |a||b|$
#
# ### Timeline
#
# * (0 ~ 5 min) Review
# * (5 ~ 10 min) Questions, roster
# * (10 ~ 55 min) Lecture on contents (English)
# * (55 ~ 75 min) Discussion (Korean)

# %% [markdown]
# ## Lecture 08 (19/3/21)
#
# ### To Do
#
# * Review previous lecture
# * Re-announce homework 02
# * Check roster
#
# ### Contents (3.3)
#
# * Projection
#   * Projection of $b$ onto $a$: $\textrm{Proj}_a(b) = \frac{a^Tb}{a^Ta}a$
#   * Example: $a = (1,1,1)$, $b=(1,2,2)$.
#   * Projection matrix: $P=\frac{aa^T}{a^Ta}$. $Pb = \textrm{Proj}_a(b)$
#   * Properties of projection matrix $P$: $P^T=P$, $P^2=P$
#   * Theorem: any $P$ satisfying $P^T=P$, $P^2=P$ represents a projection onto its column space.
#
# * Least square approximation
#   * Finding a best estimate $\hat x$ for $Ax=b$ which minizes the error $E = |b-A\hatx|$.
#   * Normal equation $A^TA\hat x = A^Tb$
#   * Best estimate: $\hat x = (A^TA)^{-1}A^b$
#   * Projection: $p = A\hat x = A(A^TA)^{-1}A^Tb$
#
# * Invertibility of $A^TA$.
#   * $N(A^TA) = N(A)$
#   * Theorem: $A^TA$ is invertible if $N(A)=0$.
#
# * Applications
#   * Line-fitting: $C+Dt = y$
#   * Weighted error: $E = |WAx - Wb|$.
#     * Weighted normal equation: $(A^TW^TWA)\hat x = A^TW^TWb$.
#     * Weighted inner product: $(x,y)_W = (Wy)^T(Wx)$.
#
# ### Timeline
#
# * (0 ~ 5 min) Review
# * (5 ~ 10 min) Questions, roster
# * (10 ~ 55 min) Lecture on contents (English)
# * (55 ~ 75 min) Discussion (Korean)
